# %%
import numpy as np # numpy is commonly used to process number array

X = np.array(([2, 9], [1, 5], [3, 6]), dtype=float) # Features ( Hrs Slept, Hrs Studied) 
y = np.array(([92], [86], [89]), dtype=float)	# Labels(Marks obtained)

X = X/np.amax(X,axis=0) # Normalize 
y = y/100

def sigmoid(x):
    return 1/(1 + np.exp(-x))
def sigmoid_grad(x):
    return x * (1 - x)

# Variable initialization
epoch=100	#Setting training iterations
eta =0.2		#Setting learning rate (eta)
input_neurons = 2	#number of features in data set 
hidden_neurons = 3	#number of hidden layers neurons
output_neurons = 1	#number of neurons at output layer

# Weight and bias - Random initialization
wh=np.random.uniform(size=(input_neurons,hidden_neurons))	# 2x3 
bh=np.random.uniform(size=(1,hidden_neurons))	# 1x3 
wout=np.random.uniform(size=(hidden_neurons,output_neurons)) # 1x1 
bout=np.random.uniform(size=(1,output_neurons))

for i in range(epoch):
#Forward Propogation
    h_ip=np.dot(X,wh) + bh	# Dot product + bias 
    h_act = sigmoid(h_ip)	# Activation function 
    o_ip=np.dot(h_act,wout) + bout
    output = sigmoid(o_ip)

#Backpropagation
    # Error at Output layer
    Eo = y-output	# Error at o/p 
    outgrad = sigmoid_grad(output)
    d_output = Eo* outgrad	# Errj=Oj(1-Oj)(Tj-Oj)

    # Error at Hidden later
    Eh = d_output.dot(wout.T)	# .T means transpose
    hiddengrad = sigmoid_grad(h_act)	# How much hidden layer wts contributed to error 
    d_hidden = Eh * hiddengrad
    wout += h_act.T.dot(d_output) *eta	# Dotproduct of nextlayererror and currentlayerop 
    wh += X.T.dot(d_hidden) *eta
    print("Error in "+str(i)+" iteration: \n",abs(y-output))
    
print("Normalized Input: \n" + str(X))
print("Actual Output: \n" + str(y))
print("Predicted Output: \n" ,output)
print("Final Error: \n" ,abs(y-output))
# Out:
# Error in 0 iteration:
#  [[0.25061231]
#  [0.19913139]
#  [0.22023632]]
# Error in 1 iteration:
#  [[0.24056074]
#  [0.1897113 ]
#  [0.2102729 ]]
# Error in 2 iteration:
#  [[0.23123207]
#  [0.18095518]
#  [0.20102537]]
# Error in 3 iteration:
#  [[0.22256083]
#  [0.17280367]
#  [0.19242887]]
# Error in 4 iteration:
#  [[0.21448756]
#  [0.16520277]
#  [0.1844245 ]]
# Error in 5 iteration:
#  [[0.20695847]
#  [0.15810363]
#  [0.17695897]]
# Error in 6 iteration:
#  [[0.19992505]
#  [0.15146212]
#  [0.16998427]]
# Error in 7 iteration:
#  [[0.19334365]
#  [0.14523848]
#  [0.16345717]]
# Error in 8 iteration:
#  [[0.187175  ]
#  [0.13939694]
#  [0.15733882]]
# Error in 9 iteration:
#  [[0.18138382]
#  [0.13390527]
#  [0.15159427]]
# Error in 10 iteration:
#  [[0.17593836]
#  [0.12873449]
#  [0.14619212]]
# Error in 11 iteration:
#  [[0.17081008]
#  [0.12385848]
#  [0.14110411]]
# Error in 12 iteration:
#  [[0.16597327]
#  [0.11925369]
#  [0.1363048 ]]
# Error in 13 iteration:
#  [[0.16140475]
#  [0.11489887]
#  [0.13177124]]
# Error in 14 iteration:
#  [[0.15708361]
#  [0.11077481]
#  [0.12748275]]
# Error in 15 iteration:
#  [[0.15299094]
#  [0.10686415]
#  [0.12342059]]
# Error in 16 iteration:
#  [[0.14910962]
#  [0.10315112]
#  [0.11956784]]
# Error in 17 iteration:
#  [[0.14542413]
#  [0.09962143]
#  [0.11590913]]
# Error in 18 iteration:
#  [[0.14192038]
#  [0.09626209]
#  [0.11243051]]
# Error in 19 iteration:
#  [[0.13858556]
#  [0.09306127]
#  [0.1091193 ]]
# Error in 20 iteration:
#  [[0.13540799]
#  [0.09000817]
#  [0.10596393]]
# Error in 21 iteration:
#  [[0.13237702]
#  [0.08709294]
#  [0.10295387]]
# Error in 22 iteration:
#  [[0.1294829 ]
#  [0.08430656]
#  [0.10007948]]
# Error in 23 iteration:
#  [[0.12671674]
#  [0.08164076]
#  [0.09733192]]
# Error in 24 iteration:
#  [[0.12407036]
#  [0.07908798]
#  [0.09470312]]
# Error in 25 iteration:
#  [[0.12153625]
#  [0.07664123]
#  [0.09218564]]
# Error in 26 iteration:
#  [[0.11910752]
#  [0.0742941 ]
#  [0.08977265]]
# Error in 27 iteration:
#  [[0.11677782]
#  [0.07204067]
#  [0.08745786]]
# Error in 28 iteration:
#  [[0.11454129]
#  [0.06987549]
#  [0.08523546]]
# Error in 29 iteration:
#  [[0.11239251]
#  [0.06779352]
#  [0.08310011]]
# Error in 30 iteration:
#  [[0.11032649]
#  [0.06579007]
#  [0.08104684]]
# Error in 31 iteration:
#  [[0.10833858]
#  [0.06386082]
#  [0.07907105]]
# Error in 32 iteration:
#  [[0.1064245 ]
#  [0.06200175]
#  [0.0771685 ]]
# Error in 33 iteration:
#  [[0.10458024]
#  [0.06020913]
#  [0.07533523]]
# Error in 34 iteration:
#  [[0.10280211]
#  [0.05847947]
#  [0.07356757]]
# Error in 35 iteration:
#  [[0.10108664]
#  [0.05680955]
#  [0.07186209]]
# Error in 36 iteration:
#  [[0.09943063]
#  [0.05519635]
#  [0.07021561]]
# Error in 37 iteration:
#  [[0.09783107]
#  [0.05363704]
#  [0.06862515]]
# Error in 38 iteration:
#  [[0.09628516]
#  [0.05212899]
#  [0.06708794]]
# Error in 39 iteration:
#  [[0.09479027]
#  [0.05066974]
#  [0.06560137]]
# Error in 40 iteration:
#  [[0.09334396]
#  [0.04925697]
#  [0.06416302]]
# Error in 41 iteration:
#  [[0.09194392]
#  [0.04788852]
#  [0.06277061]]
# Error in 42 iteration:
#  [[0.09058801]
#  [0.04656237]
#  [0.061422  ]]
# Error in 43 iteration:
#  [[0.08927419]
#  [0.04527659]
#  [0.06011519]]
# Error in 44 iteration:
#  [[0.08800057]
#  [0.04402939]
#  [0.05884829]]
# Error in 45 iteration:
#  [[0.08676535]
#  [0.04281909]
#  [0.05761952]]
# Error in 46 iteration:
#  [[0.08556686]
#  [0.04164409]
#  [0.05642723]]
# Error in 47 iteration:
#  [[0.08440351]
#  [0.04050289]
#  [0.05526983]]
# Error in 48 iteration:
#  [[0.0832738 ]
#  [0.03939407]
#  [0.05414584]]
# Error in 49 iteration:
#  [[0.08217633]
#  [0.0383163 ]
#  [0.05305386]]
# Error in 50 iteration:
#  [[0.08110974]
#  [0.03726831]
#  [0.05199258]]
# Error in 51 iteration:
#  [[0.0800728 ]
#  [0.0362489 ]
#  [0.05096073]]
# Error in 52 iteration:
#  [[0.0790643 ]
#  [0.03525694]
#  [0.04995714]]
# Error in 53 iteration:
#  [[0.07808311]
#  [0.03429137]
#  [0.04898069]]
# Error in 54 iteration:
#  [[0.07712816]
#  [0.03335115]
#  [0.0480303 ]]
# Error in 55 iteration:
#  [[0.07619845]
#  [0.03243533]
#  [0.04710499]]
# Error in 56 iteration:
#  [[0.075293  ]
#  [0.03154299]
#  [0.04620379]]
# Error in 57 iteration:
#  [[0.07441091]
#  [0.03067325]
#  [0.0453258 ]]
# Error in 58 iteration:
#  [[0.0735513 ]
#  [0.0298253 ]
#  [0.04447015]]
# Error in 59 iteration:
#  [[0.07271335]
#  [0.02899834]
#  [0.04363603]]
# Error in 60 iteration:
#  [[0.07189628]
#  [0.02819163]
#  [0.04282266]]
# Error in 61 iteration:
#  [[0.07109933]
#  [0.02740444]
#  [0.04202928]]
# Error in 62 iteration:
#  [[0.0703218 ]
#  [0.0266361 ]
#  [0.04125521]]
# Error in 63 iteration:
#  [[0.069563  ]
#  [0.02588597]
#  [0.04049976]]
# Error in 64 iteration:
#  [[0.0688223 ]
#  [0.02515342]
#  [0.0397623 ]]
# Error in 65 iteration:
#  [[0.06809906]
#  [0.02443786]
#  [0.0390422 ]]
# Error in 66 iteration:
#  [[0.06739271]
#  [0.02373872]
#  [0.03833889]]
# Error in 67 iteration:
#  [[0.06670268]
#  [0.02305547]
#  [0.0376518 ]]
# Error in 68 iteration:
#  [[0.06602843]
#  [0.02238759]
#  [0.03698041]]
# Error in 69 iteration:
#  [[0.06536944]
#  [0.02173459]
#  [0.03632419]]
# Error in 70 iteration:
#  [[0.06472523]
#  [0.02109599]
#  [0.03568267]]
# Error in 71 iteration:
#  [[0.06409532]
#  [0.02047135]
#  [0.03505537]]
# Error in 72 iteration:
#  [[0.06347927]
#  [0.01986022]
#  [0.03444184]]
# Error in 73 iteration:
#  [[0.06287663]
#  [0.0192622 ]
#  [0.03384167]]
# Error in 74 iteration:
#  [[0.062287  ]
#  [0.01867688]
#  [0.03325442]]
# Error in 75 iteration:
#  [[0.06170998]
#  [0.01810389]
#  [0.03267972]]
# Error in 76 iteration:
#  [[0.06114519]
#  [0.01754285]
#  [0.03211718]]
# Error in 77 iteration:
#  [[0.06059226]
#  [0.01699341]
#  [0.03156644]]
# Error in 78 iteration:
#  [[0.06005084]
#  [0.01645524]
#  [0.03102715]]
# Error in 79 iteration:
#  [[0.05952059]
#  [0.01592801]
#  [0.03049897]]
# Error in 80 iteration:
#  [[0.05900118]
#  [0.0154114 ]
#  [0.02998158]]
# Error in 81 iteration:
#  [[0.05849232]
#  [0.01490511]
#  [0.02947468]]
# Error in 82 iteration:
#  [[0.05799369]
#  [0.01440887]
#  [0.02897796]]
# Error in 83 iteration:
#  [[0.05750501]
#  [0.01392238]
#  [0.02849114]]
# Error in 84 iteration:
#  [[0.057026  ]
#  [0.01344538]
#  [0.02801394]]
# Error in 85 iteration:
#  [[0.05655639]
#  [0.0129776 ]
#  [0.0275461 ]]
# Error in 86 iteration:
#  [[0.05609593]
#  [0.01251881]
#  [0.02708735]]
# Error in 87 iteration:
#  [[0.05564436]
#  [0.01206876]
#  [0.02663746]]
# Error in 88 iteration:
#  [[0.05520145]
#  [0.01162722]
#  [0.02619619]]
# Error in 89 iteration:
#  [[0.05476697]
#  [0.01119396]
#  [0.0257633 ]]
# Error in 90 iteration:
#  [[0.05434069]
#  [0.01076877]
#  [0.02533858]]
# Error in 91 iteration:
#  [[0.0539224 ]
#  [0.01035145]
#  [0.02492181]]
# Error in 92 iteration:
#  [[0.0535119 ]
#  [0.00994178]
#  [0.02451279]]
# Error in 93 iteration:
#  [[0.05310898]
#  [0.00953958]
#  [0.02411131]]
# Error in 94 iteration:
#  [[0.05271344]
#  [0.00914466]
#  [0.02371719]]
# Error in 95 iteration:
#  [[0.05232511]
#  [0.00875683]
#  [0.02333024]]
# Error in 96 iteration:
#  [[0.0519438 ]
#  [0.00837593]
#  [0.02295027]]
# Error in 97 iteration:
#  [[0.05156933]
#  [0.00800178]
#  [0.02257713]]
# Error in 98 iteration:
#  [[0.05120155]
#  [0.00763422]
#  [0.02221063]]
# Error in 99 iteration:
#  [[0.05084028]
#  [0.00727308]
#  [0.02185062]]
# Normalized Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.86915972]
#  [0.85272692]
#  [0.86814938]]
# Final Error:
#  [[0.05084028]
#  [0.00727308]
#  [0.02185062]]
